# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

df=pd.read_csv("/content/test2.csv")
df
# Out:
#    milk bread biscuit cornflakes bournvita  jam maggi  tea coffee cock sugar
# 0     t     t       t        NaN       NaN  NaN   NaN  NaN    NaN  NaN   NaN
# 1     t     t       t          t       NaN  NaN   NaN  NaN    NaN  NaN   NaN
# 2   NaN     t     NaN        NaN         t  NaN   NaN    t    NaN  NaN   NaN
# 3     t     t     NaN        NaN       NaN    t     t  NaN    NaN  NaN   NaN
# 4   NaN   NaN       t        NaN       NaN  NaN     t    t    NaN  NaN   NaN
# 5   NaN     t     NaN        NaN         t  NaN   NaN    t    NaN  NaN   NaN
# 6   NaN   NaN     NaN          t       NaN  NaN     t    t    NaN  NaN   NaN
# 7   NaN     t       t        NaN       NaN  NaN     t    t    NaN  NaN   NaN
# 8   NaN     t     NaN        NaN       NaN    t     t    t    NaN  NaN   NaN
# 9     t     t     NaN        NaN       NaN  NaN   NaN  NaN    NaN  NaN   NaN
# 10  NaN   NaN       t          t       NaN  NaN   NaN  NaN      t    t   NaN
# ...

# %%
df_Binary= df.replace({'t': True, np.nan: False})
df_Binary.head()
# Out:
#     milk  bread  biscuit  cornflakes  bournvita    jam  maggi    tea  coffee  \
# 0   True   True     True       False      False  False  False  False   False
# 1   True   True     True        True      False  False  False  False   False
# 2  False   True    False       False       True  False  False   True   False
# 3   True   True    False       False      False   True   True  False   False
# 4  False  False     True       False      False  False   True   True   False
#
#     cock  sugar
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets=apriori(df_Binary,min_support=0.1,use_colnames=True)
frequent_itemsets
# Out:
#     support                             itemsets
# 0      0.25                               (milk)
# 1      0.65                              (bread)
# 2      0.35                            (biscuit)
# 3      0.30                         (cornflakes)
# 4      0.20                          (bournvita)
# 5      0.10                                (jam)
# 6      0.25                              (maggi)
# 7      0.35                                (tea)
# 8      0.40                             (coffee)
# 9      0.15                               (cock)
# 10     0.30                              (sugar)
# 11     0.20                        (bread, milk)
# 12     0.10                      (biscuit, milk)
# 13     0.10                   (cornflakes, milk)
# 14     0.20                     (bread, biscuit)
# 15     0.15                   (bournvita, bread)
# 16     0.10                         (bread, jam)
# 17     0.15                       (maggi, bread)
# ...

# %%
from mlxtend.frequent_patterns import association_rules
confidence= association_rules(frequent_itemsets,metric="confidence",min_threshold=0.1,num_itemsets=2)
confidence
# Out:
#                antecedents                    consequents  antecedent support  \
# 0                  (bread)                         (milk)                0.65
# 1                   (milk)                        (bread)                0.25
# 2                (biscuit)                         (milk)                0.35
# 3                   (milk)                      (biscuit)                0.25
# 4             (cornflakes)                         (milk)                0.30
# ..                     ...                            ...                 ...
# 117  (cornflakes, biscuit)                 (cock, coffee)                0.15
# 118                 (cock)  (coffee, biscuit, cornflakes)                0.15
# 119               (coffee)    (cock, cornflakes, biscuit)                0.40
# 120              (biscuit)     (cock, coffee, cornflakes)                0.35
# 121           (cornflakes)        (cock, coffee, biscuit)                0.30
#
# ...

# %%
confidence.columns
# Out:
# Index(['antecedents', 'consequents', 'antecedent support',
#        'consequent support', 'support', 'confidence', 'lift',
#        'representativity', 'leverage', 'conviction', 'zhangs_metric',
#        'jaccard', 'certainty', 'kulczynski'],
#       dtype='object')

# %%
result=confidence[['antecedents', 'consequents','support', 'confidence', 'lift']]
result
# Out:
#                antecedents                    consequents  support  \
# 0                  (bread)                         (milk)      0.2
# 1                   (milk)                        (bread)      0.2
# 2                (biscuit)                         (milk)      0.1
# 3                   (milk)                      (biscuit)      0.1
# 4             (cornflakes)                         (milk)      0.1
# ..                     ...                            ...      ...
# 117  (cornflakes, biscuit)                 (cock, coffee)      0.1
# 118                 (cock)  (coffee, biscuit, cornflakes)      0.1
# 119               (coffee)    (cock, cornflakes, biscuit)      0.1
# 120              (biscuit)     (cock, coffee, cornflakes)      0.1
# 121           (cornflakes)        (cock, coffee, biscuit)      0.1
#
#      confidence      lift
# 0      0.307692  1.230769
# 1      0.800000  1.230769
# 2      0.285714  1.142857
# 3      0.400000  1.142857
# ...

# %%
result1=result[result.lift>1]
result1
# Out:
#                antecedents                    consequents  support  \
# 0                  (bread)                         (milk)      0.2
# 1                   (milk)                        (bread)      0.2
# 2                (biscuit)                         (milk)      0.1
# 3                   (milk)                      (biscuit)      0.1
# 4             (cornflakes)                         (milk)      0.1
# ..                     ...                            ...      ...
# 117  (cornflakes, biscuit)                 (cock, coffee)      0.1
# 118                 (cock)  (coffee, biscuit, cornflakes)      0.1
# 119               (coffee)    (cock, cornflakes, biscuit)      0.1
# 120              (biscuit)     (cock, coffee, cornflakes)      0.1
# 121           (cornflakes)        (cock, coffee, biscuit)      0.1
#
#      confidence      lift
# 0      0.307692  1.230769
# 1      0.800000  1.230769
# 2      0.285714  1.142857
# 3      0.400000  1.142857
# ...

# %%
result2=result[result.lift==1]
result2
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %%
result1=result[result.lift<1]
result1
# Out:
#         antecedents      consequents  support  confidence      lift
# 6           (bread)        (biscuit)     0.20    0.307692  0.879121
# 7         (biscuit)          (bread)     0.20    0.571429  0.879121
# 12          (maggi)          (bread)     0.15    0.600000  0.923077
# 13          (bread)          (maggi)     0.15    0.230769  0.923077
# 14          (bread)            (tea)     0.20    0.307692  0.879121
# 15            (tea)          (bread)     0.20    0.571429  0.879121
# 16         (coffee)          (bread)     0.15    0.375000  0.576923
# 17          (bread)         (coffee)     0.15    0.230769  0.576923
# 24            (tea)        (biscuit)     0.10    0.285714  0.816327
# 25        (biscuit)            (tea)     0.10    0.285714  0.816327
# 26         (coffee)        (biscuit)     0.10    0.250000  0.714286
# 27        (biscuit)         (coffee)     0.10    0.285714  0.714286
# 30     (cornflakes)            (tea)     0.10    0.333333  0.952381
# ...
